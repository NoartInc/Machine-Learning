# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.0.1.post2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (0.2.2.post3)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (4.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.14.6)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.1.1->torchvision) (0.46)

# %%
import torch, torchvision
from torch import nn,optim
from torch.autograd import Variable as var

# %%
n_batch = 64
learning_rate = 0.01
n_epoch = 3
n_print = 10

# %%
#### Part I : Loading Your Data 

T = torchvision.transforms.ToTensor()
train_data = torchvision.datasets.MNIST('mnist_data',train=True,download=True,transform=T)
val_data = torchvision.datasets.MNIST('mnist_data',train=False,download=True,transform=T)

train_dl = torch.utils.data.DataLoader(train_data,batch_size = n_batch)
val_dl = torch.utils.data.DataLoader(val_data,batch_size = n_batch)

# %%
#### Part II : Writing the Network
class myCNN(nn.Module):
  def __init__(self):
    super(myCNN,self).__init__()
    self.cnn1 = nn.Conv2d(1,3,3)
    self.cnn2 = nn.Conv2d(3,2,5)
    self.linear = nn.Linear(968,10)
    self.relu = nn.ReLU()
  
  def forward(self,x):
    n = x.size(0)
    x = self.relu(self.cnn1(x))
    x = self.relu(self.cnn2(x))
    x = x.view(n,-1)
    x = self.linear(x)
    return x

# %%
#### Part III : Writing the main Training loop

mycnn = myCNN().cuda()
cec = nn.CrossEntropyLoss()
optimizer = optim.Adam(mycnn.parameters(),lr = learning_rate)

def validate(model,data):
  # To get validation accuracy = (correct/total)*100.
  total = 0
  correct = 0
  for i,(images,labels) in enumerate(data):
    images = var(images.cuda())
    x = model(images)
    value,pred = torch.max(x,1)
    pred = pred.data.cpu()
    total += x.size(0)
    correct += torch.sum(pred == labels)
  return correct*100./total

for e in range(n_epoch):
  for i,(images,labels) in enumerate(train_dl):
    images = var(images.cuda())
    labels = var(labels.cuda())
    optimizer.zero_grad()
    pred = mycnn(images)
    loss = cec(pred,labels)
    loss.backward()
    optimizer.step()
    if (i+1) % n_print == 0:
      accuracy = float(validate(mycnn,val_dl))
      print('Epoch :',e+1,'Batch :',i+1,'Loss :',float(loss.data),'Accuracy :',accuracy,'%')
# Out:
# Epoch : 1 Batch : 10 Loss : 1.3160289525985718 Accuracy : 71.0 %
# Epoch : 1 Batch : 20 Loss : 1.221832036972046 Accuracy : 77.0 %
# Epoch : 1 Batch : 30 Loss : 0.4357207417488098 Accuracy : 83.0 %
# Epoch : 1 Batch : 40 Loss : 0.2440439909696579 Accuracy : 83.0 %
# Epoch : 1 Batch : 50 Loss : 0.3064013719558716 Accuracy : 84.0 %
# Epoch : 1 Batch : 60 Loss : 0.49648457765579224 Accuracy : 86.0 %
# Epoch : 1 Batch : 70 Loss : 0.24577412009239197 Accuracy : 88.0 %
# Epoch : 1 Batch : 80 Loss : 0.37063342332839966 Accuracy : 88.0 %
# Epoch : 1 Batch : 90 Loss : 0.37435781955718994 Accuracy : 88.0 %
# Epoch : 1 Batch : 100 Loss : 0.19899247586727142 Accuracy : 88.0 %
# Epoch : 1 Batch : 110 Loss : 0.639371931552887 Accuracy : 89.0 %
# Epoch : 1 Batch : 120 Loss : 0.40772950649261475 Accuracy : 89.0 %
# Epoch : 1 Batch : 130 Loss : 0.38146260380744934 Accuracy : 90.0 %
# Epoch : 1 Batch : 140 Loss : 0.4410313665866852 Accuracy : 88.0 %
# Epoch : 1 Batch : 150 Loss : 0.32954779267311096 Accuracy : 89.0 %
# Epoch : 1 Batch : 160 Loss : 0.5636780261993408 Accuracy : 89.0 %
# Epoch : 1 Batch : 170 Loss : 0.38839542865753174 Accuracy : 88.0 %
# Epoch : 1 Batch : 180 Loss : 0.3180372416973114 Accuracy : 90.0 %
# Epoch : 1 Batch : 190 Loss : 0.21109849214553833 Accuracy : 88.0 %
# Epoch : 1 Batch : 200 Loss : 0.44635099172592163 Accuracy : 87.0 %
# Epoch : 1 Batch : 210 Loss : 0.34030431509017944 Accuracy : 90.0 %
# Epoch : 1 Batch : 220 Loss : 0.4407007694244385 Accuracy : 91.0 %
# Epoch : 1 Batch : 230 Loss : 0.5479503870010376 Accuracy : 91.0 %
# Epoch : 1 Batch : 240 Loss : 0.2611640691757202 Accuracy : 91.0 %
# Epoch : 1 Batch : 250 Loss : 0.8871949315071106 Accuracy : 91.0 %
# Epoch : 1 Batch : 260 Loss : 0.2092086225748062 Accuracy : 91.0 %
# Epoch : 1 Batch : 270 Loss : 0.5030462145805359 Accuracy : 91.0 %
# Epoch : 1 Batch : 280 Loss : 0.20184695720672607 Accuracy : 92.0 %
# Epoch : 1 Batch : 290 Loss : 0.1035340279340744 Accuracy : 90.0 %
# Epoch : 1 Batch : 300 Loss : 0.3127279579639435 Accuracy : 91.0 %
# Epoch : 1 Batch : 310 Loss : 0.4241302013397217 Accuracy : 90.0 %
# Epoch : 1 Batch : 320 Loss : 0.19661864638328552 Accuracy : 91.0 %
# Epoch : 1 Batch : 330 Loss : 0.2838369607925415 Accuracy : 90.0 %
# Epoch : 1 Batch : 340 Loss : 0.27716511487960815 Accuracy : 92.0 %
# Epoch : 1 Batch : 350 Loss : 0.06614281982183456 Accuracy : 92.0 %
# Epoch : 1 Batch : 360 Loss : 0.3259104788303375 Accuracy : 88.0 %
# Epoch : 1 Batch : 370 Loss : 0.2735474407672882 Accuracy : 91.0 %
# Epoch : 1 Batch : 380 Loss : 0.35427138209342957 Accuracy : 91.0 %
# Epoch : 1 Batch : 390 Loss : 0.40406328439712524 Accuracy : 92.0 %
# Epoch : 1 Batch : 400 Loss : 0.32563865184783936 Accuracy : 91.0 %
# Epoch : 1 Batch : 410 Loss : 0.15847830474376678 Accuracy : 92.0 %
# Epoch : 1 Batch : 420 Loss : 0.4056328237056732 Accuracy : 91.0 %
# Epoch : 1 Batch : 430 Loss : 0.3328588306903839 Accuracy : 91.0 %
# Epoch : 1 Batch : 440 Loss : 0.32358837127685547 Accuracy : 91.0 %
# Epoch : 1 Batch : 450 Loss : 0.3194127678871155 Accuracy : 91.0 %
# Epoch : 1 Batch : 460 Loss : 0.36306032538414 Accuracy : 90.0 %
# Epoch : 1 Batch : 470 Loss : 0.4493681490421295 Accuracy : 91.0 %
# Epoch : 1 Batch : 480 Loss : 0.4060530960559845 Accuracy : 91.0 %
# Epoch : 1 Batch : 490 Loss : 0.7039828896522522 Accuracy : 92.0 %
# Epoch : 1 Batch : 500 Loss : 0.33015623688697815 Accuracy : 92.0 %
# Epoch : 1 Batch : 510 Loss : 0.08130224049091339 Accuracy : 91.0 %
# Epoch : 1 Batch : 520 Loss : 0.3580274283885956 Accuracy : 92.0 %
# Epoch : 1 Batch : 530 Loss : 0.09675516933202744 Accuracy : 90.0 %
# Epoch : 1 Batch : 540 Loss : 0.530693769454956 Accuracy : 92.0 %
# Epoch : 1 Batch : 550 Loss : 0.20615223050117493 Accuracy : 92.0 %
# Epoch : 1 Batch : 560 Loss : 0.10058125108480453 Accuracy : 92.0 %
# Epoch : 1 Batch : 570 Loss : 0.3970341086387634 Accuracy : 92.0 %
# Epoch : 1 Batch : 580 Loss : 0.4159395694732666 Accuracy : 92.0 %
# Epoch : 1 Batch : 590 Loss : 0.3307126760482788 Accuracy : 91.0 %
# Epoch : 1 Batch : 600 Loss : 0.27630165219306946 Accuracy : 92.0 %
# Epoch : 1 Batch : 610 Loss : 0.2435663789510727 Accuracy : 91.0 %
# Epoch : 1 Batch : 620 Loss : 0.4382493197917938 Accuracy : 90.0 %
# Epoch : 1 Batch : 630 Loss : 0.368713915348053 Accuracy : 91.0 %
# Epoch : 1 Batch : 640 Loss : 0.18796610832214355 Accuracy : 92.0 %
# Epoch : 1 Batch : 650 Loss : 0.28022733330726624 Accuracy : 92.0 %
# Epoch : 1 Batch : 660 Loss : 0.31290143728256226 Accuracy : 91.0 %
# Epoch : 1 Batch : 670 Loss : 0.4004572927951813 Accuracy : 91.0 %
# Epoch : 1 Batch : 680 Loss : 0.1634504497051239 Accuracy : 91.0 %
# Epoch : 1 Batch : 690 Loss : 0.395752876996994 Accuracy : 92.0 %
# Epoch : 1 Batch : 700 Loss : 0.27463966608047485 Accuracy : 91.0 %
# Epoch : 1 Batch : 710 Loss : 0.26082009077072144 Accuracy : 92.0 %
# Epoch : 1 Batch : 720 Loss : 0.3435180187225342 Accuracy : 92.0 %
# Epoch : 1 Batch : 730 Loss : 0.14577046036720276 Accuracy : 92.0 %
# Epoch : 1 Batch : 740 Loss : 0.30840635299682617 Accuracy : 92.0 %
# Epoch : 1 Batch : 750 Loss : 0.3044908046722412 Accuracy : 92.0 %
# Epoch : 1 Batch : 760 Loss : 0.16426193714141846 Accuracy : 92.0 %
# Epoch : 1 Batch : 770 Loss : 0.3432709872722626 Accuracy : 91.0 %
# Epoch : 1 Batch : 780 Loss : 0.6322892904281616 Accuracy : 92.0 %
# Epoch : 1 Batch : 790 Loss : 0.4246010184288025 Accuracy : 91.0 %
# Epoch : 1 Batch : 800 Loss : 0.2659291923046112 Accuracy : 92.0 %
# Epoch : 1 Batch : 810 Loss : 0.12627989053726196 Accuracy : 92.0 %
# Epoch : 1 Batch : 820 Loss : 0.12281498312950134 Accuracy : 92.0 %
# Epoch : 1 Batch : 830 Loss : 0.21959710121154785 Accuracy : 92.0 %
# Epoch : 1 Batch : 840 Loss : 0.2993968427181244 Accuracy : 92.0 %
# Epoch : 1 Batch : 850 Loss : 0.23792974650859833 Accuracy : 92.0 %
# Epoch : 1 Batch : 860 Loss : 0.36012089252471924 Accuracy : 92.0 %
# Epoch : 1 Batch : 870 Loss : 0.21575558185577393 Accuracy : 92.0 %
# Epoch : 1 Batch : 880 Loss : 0.207179993391037 Accuracy : 92.0 %
# Epoch : 1 Batch : 890 Loss : 0.16710920631885529 Accuracy : 93.0 %
# Epoch : 1 Batch : 900 Loss : 0.14483755826950073 Accuracy : 93.0 %
# Epoch : 1 Batch : 910 Loss : 0.05816821753978729 Accuracy : 93.0 %
# Epoch : 1 Batch : 920 Loss : 0.2805669605731964 Accuracy : 92.0 %
# Epoch : 1 Batch : 930 Loss : 0.20268478989601135 Accuracy : 92.0 %
# Epoch : 2 Batch : 10 Loss : 0.32173916697502136 Accuracy : 92.0 %
# Epoch : 2 Batch : 20 Loss : 0.567261278629303 Accuracy : 92.0 %
# Epoch : 2 Batch : 30 Loss : 0.08400058001279831 Accuracy : 93.0 %
# Epoch : 2 Batch : 40 Loss : 0.11273647844791412 Accuracy : 92.0 %
# Epoch : 2 Batch : 50 Loss : 0.09255523979663849 Accuracy : 92.0 %
# Epoch : 2 Batch : 60 Loss : 0.16675139963626862 Accuracy : 92.0 %
# Epoch : 2 Batch : 70 Loss : 0.1850942224264145 Accuracy : 93.0 %
# Epoch : 2 Batch : 80 Loss : 0.3172184228897095 Accuracy : 93.0 %
# Epoch : 2 Batch : 90 Loss : 0.1824451982975006 Accuracy : 92.0 %
# Epoch : 2 Batch : 100 Loss : 0.12593349814414978 Accuracy : 92.0 %
# Epoch : 2 Batch : 110 Loss : 0.41068369150161743 Accuracy : 92.0 %
# Epoch : 2 Batch : 120 Loss : 0.21185806393623352 Accuracy : 92.0 %
# Epoch : 2 Batch : 130 Loss : 0.23571990430355072 Accuracy : 93.0 %
# Epoch : 2 Batch : 140 Loss : 0.46933943033218384 Accuracy : 91.0 %
# Epoch : 2 Batch : 150 Loss : 0.22596995532512665 Accuracy : 92.0 %
# Epoch : 2 Batch : 160 Loss : 0.4020622968673706 Accuracy : 91.0 %
# Epoch : 2 Batch : 170 Loss : 0.3136383295059204 Accuracy : 92.0 %
# Epoch : 2 Batch : 180 Loss : 0.15315663814544678 Accuracy : 92.0 %
# Epoch : 2 Batch : 190 Loss : 0.14573459327220917 Accuracy : 91.0 %
# Epoch : 2 Batch : 200 Loss : 0.33059972524642944 Accuracy : 91.0 %
# Epoch : 2 Batch : 210 Loss : 0.2907487154006958 Accuracy : 92.0 %
# Epoch : 2 Batch : 220 Loss : 0.27760469913482666 Accuracy : 92.0 %
# Epoch : 2 Batch : 230 Loss : 0.46066227555274963 Accuracy : 92.0 %
# Epoch : 2 Batch : 240 Loss : 0.19345012307167053 Accuracy : 93.0 %
# Epoch : 2 Batch : 250 Loss : 0.6745897531509399 Accuracy : 93.0 %
# Epoch : 2 Batch : 260 Loss : 0.1557113081216812 Accuracy : 92.0 %
# Epoch : 2 Batch : 270 Loss : 0.44549548625946045 Accuracy : 93.0 %
# Epoch : 2 Batch : 280 Loss : 0.1504376083612442 Accuracy : 93.0 %
# Epoch : 2 Batch : 290 Loss : 0.09278088808059692 Accuracy : 92.0 %
# Epoch : 2 Batch : 300 Loss : 0.27549877762794495 Accuracy : 93.0 %
# Epoch : 2 Batch : 310 Loss : 0.47967538237571716 Accuracy : 93.0 %
# Epoch : 2 Batch : 320 Loss : 0.16711097955703735 Accuracy : 93.0 %
# Epoch : 2 Batch : 330 Loss : 0.2237623929977417 Accuracy : 91.0 %
# Epoch : 2 Batch : 340 Loss : 0.22295382618904114 Accuracy : 93.0 %
# Epoch : 2 Batch : 350 Loss : 0.08687213808298111 Accuracy : 93.0 %
# Epoch : 2 Batch : 360 Loss : 0.26589757204055786 Accuracy : 91.0 %
# Epoch : 2 Batch : 370 Loss : 0.20873203873634338 Accuracy : 92.0 %
# Epoch : 2 Batch : 380 Loss : 0.3425448536872864 Accuracy : 93.0 %
# Epoch : 2 Batch : 390 Loss : 0.3760569989681244 Accuracy : 93.0 %
# Epoch : 2 Batch : 400 Loss : 0.27456432580947876 Accuracy : 92.0 %
# Epoch : 2 Batch : 410 Loss : 0.08842875808477402 Accuracy : 92.0 %
# Epoch : 2 Batch : 420 Loss : 0.27447620034217834 Accuracy : 92.0 %
# Epoch : 2 Batch : 430 Loss : 0.25254666805267334 Accuracy : 93.0 %
# Epoch : 2 Batch : 440 Loss : 0.2279333770275116 Accuracy : 93.0 %
# Epoch : 2 Batch : 450 Loss : 0.2520158886909485 Accuracy : 91.0 %
# Epoch : 2 Batch : 460 Loss : 0.33052393794059753 Accuracy : 92.0 %
# Epoch : 2 Batch : 470 Loss : 0.3696195185184479 Accuracy : 93.0 %
# Epoch : 2 Batch : 480 Loss : 0.356547087430954 Accuracy : 92.0 %
# Epoch : 2 Batch : 490 Loss : 0.5261207818984985 Accuracy : 92.0 %
# Epoch : 2 Batch : 500 Loss : 0.2534339427947998 Accuracy : 93.0 %
# Epoch : 2 Batch : 510 Loss : 0.05286936089396477 Accuracy : 92.0 %
# Epoch : 2 Batch : 520 Loss : 0.34219875931739807 Accuracy : 92.0 %
# Epoch : 2 Batch : 530 Loss : 0.08708521723747253 Accuracy : 92.0 %
# Epoch : 2 Batch : 540 Loss : 0.4343208074569702 Accuracy : 92.0 %
# Epoch : 2 Batch : 550 Loss : 0.1735266149044037 Accuracy : 93.0 %
# Epoch : 2 Batch : 560 Loss : 0.09646821767091751 Accuracy : 93.0 %
# Epoch : 2 Batch : 570 Loss : 0.3841395974159241 Accuracy : 92.0 %
# Epoch : 2 Batch : 580 Loss : 0.3827337920665741 Accuracy : 92.0 %
# Epoch : 2 Batch : 590 Loss : 0.28313982486724854 Accuracy : 92.0 %
# Epoch : 2 Batch : 600 Loss : 0.23298995196819305 Accuracy : 92.0 %
# Epoch : 2 Batch : 610 Loss : 0.18439918756484985 Accuracy : 92.0 %
# Epoch : 2 Batch : 620 Loss : 0.4270254075527191 Accuracy : 91.0 %
# Epoch : 2 Batch : 630 Loss : 0.30436477065086365 Accuracy : 91.0 %
# Epoch : 2 Batch : 640 Loss : 0.14183101058006287 Accuracy : 92.0 %
# Epoch : 2 Batch : 650 Loss : 0.33692994713783264 Accuracy : 92.0 %
# Epoch : 2 Batch : 660 Loss : 0.3582647144794464 Accuracy : 92.0 %
# Epoch : 2 Batch : 670 Loss : 0.38044095039367676 Accuracy : 91.0 %
# Epoch : 2 Batch : 680 Loss : 0.14228737354278564 Accuracy : 92.0 %
# Epoch : 2 Batch : 690 Loss : 0.3276388645172119 Accuracy : 92.0 %
# Epoch : 2 Batch : 700 Loss : 0.2484377920627594 Accuracy : 91.0 %
# Epoch : 2 Batch : 710 Loss : 0.23186106979846954 Accuracy : 92.0 %
# Epoch : 2 Batch : 720 Loss : 0.3116087019443512 Accuracy : 92.0 %
# Epoch : 2 Batch : 730 Loss : 0.12623324990272522 Accuracy : 93.0 %
# Epoch : 2 Batch : 740 Loss : 0.27123939990997314 Accuracy : 92.0 %
# Epoch : 2 Batch : 750 Loss : 0.2882843315601349 Accuracy : 93.0 %
# Epoch : 2 Batch : 760 Loss : 0.13435885310173035 Accuracy : 93.0 %
# Epoch : 2 Batch : 770 Loss : 0.2904594838619232 Accuracy : 91.0 %
# Epoch : 2 Batch : 780 Loss : 0.6005584001541138 Accuracy : 93.0 %
# Epoch : 2 Batch : 790 Loss : 0.3528120815753937 Accuracy : 92.0 %
# Epoch : 2 Batch : 800 Loss : 0.239335834980011 Accuracy : 92.0 %
# Epoch : 2 Batch : 810 Loss : 0.1052229106426239 Accuracy : 93.0 %
# Epoch : 2 Batch : 820 Loss : 0.08724338561296463 Accuracy : 93.0 %
# Epoch : 2 Batch : 830 Loss : 0.18688276410102844 Accuracy : 93.0 %
# Epoch : 2 Batch : 840 Loss : 0.26930809020996094 Accuracy : 93.0 %
# Epoch : 2 Batch : 850 Loss : 0.20075620710849762 Accuracy : 92.0 %
# Epoch : 2 Batch : 860 Loss : 0.34341782331466675 Accuracy : 93.0 %
# Epoch : 2 Batch : 870 Loss : 0.24159687757492065 Accuracy : 92.0 %
# Epoch : 2 Batch : 880 Loss : 0.1700173020362854 Accuracy : 92.0 %
# Epoch : 2 Batch : 890 Loss : 0.13878126442432404 Accuracy : 93.0 %
# Epoch : 2 Batch : 900 Loss : 0.13063058257102966 Accuracy : 93.0 %
# Epoch : 2 Batch : 910 Loss : 0.06458395719528198 Accuracy : 93.0 %
# Epoch : 2 Batch : 920 Loss : 0.27322331070899963 Accuracy : 93.0 %
# Epoch : 2 Batch : 930 Loss : 0.1921730637550354 Accuracy : 92.0 %
# Epoch : 3 Batch : 10 Loss : 0.28309425711631775 Accuracy : 93.0 %
# Epoch : 3 Batch : 20 Loss : 0.4463481903076172 Accuracy : 92.0 %
# Epoch : 3 Batch : 30 Loss : 0.08066409081220627 Accuracy : 93.0 %
# Epoch : 3 Batch : 40 Loss : 0.1238689124584198 Accuracy : 93.0 %
# Epoch : 3 Batch : 50 Loss : 0.08235682547092438 Accuracy : 92.0 %
# Epoch : 3 Batch : 60 Loss : 0.1559518724679947 Accuracy : 93.0 %
# Epoch : 3 Batch : 70 Loss : 0.17503052949905396 Accuracy : 93.0 %
# Epoch : 3 Batch : 80 Loss : 0.2676892578601837 Accuracy : 93.0 %
# Epoch : 3 Batch : 90 Loss : 0.16340291500091553 Accuracy : 93.0 %
# Epoch : 3 Batch : 100 Loss : 0.13063132762908936 Accuracy : 93.0 %
# Epoch : 3 Batch : 110 Loss : 0.3881416320800781 Accuracy : 93.0 %
# Epoch : 3 Batch : 120 Loss : 0.2336585521697998 Accuracy : 92.0 %
# Epoch : 3 Batch : 130 Loss : 0.23143059015274048 Accuracy : 93.0 %
# Epoch : 3 Batch : 140 Loss : 0.39639490842819214 Accuracy : 91.0 %
# Epoch : 3 Batch : 150 Loss : 0.2139727771282196 Accuracy : 92.0 %
# Epoch : 3 Batch : 160 Loss : 0.39135873317718506 Accuracy : 92.0 %
# Epoch : 3 Batch : 170 Loss : 0.3179626166820526 Accuracy : 92.0 %
# Epoch : 3 Batch : 180 Loss : 0.12303116172552109 Accuracy : 93.0 %
# Epoch : 3 Batch : 190 Loss : 0.15772786736488342 Accuracy : 91.0 %
# Epoch : 3 Batch : 200 Loss : 0.25947561860084534 Accuracy : 90.0 %
# Epoch : 3 Batch : 210 Loss : 0.2565236985683441 Accuracy : 92.0 %
# Epoch : 3 Batch : 220 Loss : 0.2734110951423645 Accuracy : 93.0 %
# Epoch : 3 Batch : 230 Loss : 0.42561137676239014 Accuracy : 92.0 %
# Epoch : 3 Batch : 240 Loss : 0.22370275855064392 Accuracy : 93.0 %
# Epoch : 3 Batch : 250 Loss : 0.5927063822746277 Accuracy : 93.0 %
# Epoch : 3 Batch : 260 Loss : 0.14117218554019928 Accuracy : 92.0 %
# Epoch : 3 Batch : 270 Loss : 0.43746110796928406 Accuracy : 93.0 %
# Epoch : 3 Batch : 280 Loss : 0.1874527633190155 Accuracy : 93.0 %
# Epoch : 3 Batch : 290 Loss : 0.08097198605537415 Accuracy : 93.0 %
# Epoch : 3 Batch : 300 Loss : 0.282015323638916 Accuracy : 93.0 %
# Epoch : 3 Batch : 310 Loss : 0.4575062692165375 Accuracy : 93.0 %
# Epoch : 3 Batch : 320 Loss : 0.12860320508480072 Accuracy : 93.0 %
# Epoch : 3 Batch : 330 Loss : 0.2179884910583496 Accuracy : 92.0 %
# Epoch : 3 Batch : 340 Loss : 0.19395142793655396 Accuracy : 93.0 %
# Epoch : 3 Batch : 350 Loss : 0.07522555440664291 Accuracy : 93.0 %
# Epoch : 3 Batch : 360 Loss : 0.267885684967041 Accuracy : 92.0 %
# Epoch : 3 Batch : 370 Loss : 0.1795552670955658 Accuracy : 93.0 %
# Epoch : 3 Batch : 380 Loss : 0.3186478018760681 Accuracy : 93.0 %
# Epoch : 3 Batch : 390 Loss : 0.3193293809890747 Accuracy : 93.0 %
# Epoch : 3 Batch : 400 Loss : 0.2821814715862274 Accuracy : 93.0 %
# Epoch : 3 Batch : 410 Loss : 0.07885459810495377 Accuracy : 92.0 %
# Epoch : 3 Batch : 420 Loss : 0.24182796478271484 Accuracy : 92.0 %
# Epoch : 3 Batch : 430 Loss : 0.2620738446712494 Accuracy : 93.0 %
# Epoch : 3 Batch : 440 Loss : 0.19988128542900085 Accuracy : 93.0 %
# Epoch : 3 Batch : 450 Loss : 0.2557937800884247 Accuracy : 92.0 %
# Epoch : 3 Batch : 460 Loss : 0.2870200276374817 Accuracy : 92.0 %
# Epoch : 3 Batch : 470 Loss : 0.3077830672264099 Accuracy : 93.0 %
# Epoch : 3 Batch : 480 Loss : 0.38978374004364014 Accuracy : 92.0 %
# Epoch : 3 Batch : 490 Loss : 0.5027469992637634 Accuracy : 91.0 %
# Epoch : 3 Batch : 500 Loss : 0.23190835118293762 Accuracy : 93.0 %
# Epoch : 3 Batch : 510 Loss : 0.04058986157178879 Accuracy : 92.0 %
# Epoch : 3 Batch : 520 Loss : 0.3011118173599243 Accuracy : 92.0 %
# Epoch : 3 Batch : 530 Loss : 0.06707113236188889 Accuracy : 92.0 %
# Epoch : 3 Batch : 540 Loss : 0.4691081941127777 Accuracy : 92.0 %
# Epoch : 3 Batch : 550 Loss : 0.16984176635742188 Accuracy : 93.0 %
# Epoch : 3 Batch : 560 Loss : 0.1250424087047577 Accuracy : 93.0 %
# Epoch : 3 Batch : 570 Loss : 0.36346760392189026 Accuracy : 93.0 %
# Epoch : 3 Batch : 580 Loss : 0.3682647943496704 Accuracy : 92.0 %
# Epoch : 3 Batch : 590 Loss : 0.27327635884284973 Accuracy : 93.0 %
# Epoch : 3 Batch : 600 Loss : 0.21088118851184845 Accuracy : 93.0 %
# Epoch : 3 Batch : 610 Loss : 0.18082016706466675 Accuracy : 93.0 %
# Epoch : 3 Batch : 620 Loss : 0.42630961537361145 Accuracy : 91.0 %
# Epoch : 3 Batch : 630 Loss : 0.2860119342803955 Accuracy : 92.0 %
# Epoch : 3 Batch : 640 Loss : 0.11292846500873566 Accuracy : 92.0 %
# Epoch : 3 Batch : 650 Loss : 0.362701952457428 Accuracy : 93.0 %
# Epoch : 3 Batch : 660 Loss : 0.3639180064201355 Accuracy : 93.0 %
# Epoch : 3 Batch : 670 Loss : 0.3856726586818695 Accuracy : 91.0 %
# Epoch : 3 Batch : 680 Loss : 0.13930416107177734 Accuracy : 92.0 %
# Epoch : 3 Batch : 690 Loss : 0.3314965069293976 Accuracy : 92.0 %
# Epoch : 3 Batch : 700 Loss : 0.20429407060146332 Accuracy : 92.0 %
# Epoch : 3 Batch : 710 Loss : 0.2384740263223648 Accuracy : 93.0 %
# Epoch : 3 Batch : 720 Loss : 0.2787500321865082 Accuracy : 93.0 %
# Epoch : 3 Batch : 730 Loss : 0.11840347200632095 Accuracy : 93.0 %
# Epoch : 3 Batch : 740 Loss : 0.2637399733066559 Accuracy : 93.0 %
# Epoch : 3 Batch : 750 Loss : 0.2856649160385132 Accuracy : 93.0 %
# Epoch : 3 Batch : 760 Loss : 0.10939645767211914 Accuracy : 93.0 %
# Epoch : 3 Batch : 770 Loss : 0.26268696784973145 Accuracy : 92.0 %
# Epoch : 3 Batch : 780 Loss : 0.5265123844146729 Accuracy : 93.0 %
# Epoch : 3 Batch : 790 Loss : 0.2914913296699524 Accuracy : 92.0 %
# Epoch : 3 Batch : 800 Loss : 0.21829122304916382 Accuracy : 93.0 %
# Epoch : 3 Batch : 810 Loss : 0.08811021596193314 Accuracy : 93.0 %
# Epoch : 3 Batch : 820 Loss : 0.08903627097606659 Accuracy : 93.0 %
# Epoch : 3 Batch : 830 Loss : 0.19309557974338531 Accuracy : 93.0 %
# Epoch : 3 Batch : 840 Loss : 0.2558452785015106 Accuracy : 93.0 %
# Epoch : 3 Batch : 850 Loss : 0.2043861299753189 Accuracy : 93.0 %
# Epoch : 3 Batch : 860 Loss : 0.3208194971084595 Accuracy : 93.0 %
# Epoch : 3 Batch : 870 Loss : 0.21514174342155457 Accuracy : 92.0 %
# Epoch : 3 Batch : 880 Loss : 0.15420688688755035 Accuracy : 92.0 %
# Epoch : 3 Batch : 890 Loss : 0.13857005536556244 Accuracy : 93.0 %
# Epoch : 3 Batch : 900 Loss : 0.131870836019516 Accuracy : 93.0 %
# Epoch : 3 Batch : 910 Loss : 0.07630832493305206 Accuracy : 93.0 %
# Epoch : 3 Batch : 920 Loss : 0.2421754002571106 Accuracy : 93.0 %
# Epoch : 3 Batch : 930 Loss : 0.18630871176719666 Accuracy : 92.0 %

# %%
# !nvidia-smi
# Out:
# Sun Sep 23 17:35:17 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 384.111                Driver Version: 384.111                   |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P8    27W / 149W |      0MiB / 11439MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
